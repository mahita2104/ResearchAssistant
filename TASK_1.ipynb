# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import os
import time
import google.generativeai as genai
from google.colab import drive, userdata
# Configure the Gemini API
import csv

genai.configure(api_key="your google api key")

drive.mount('/content/drive')

def upload_to_gemini(path, mime_type=None):
    """Uploads the given file to Gemini."""
    file = genai.upload_file(path, mime_type=mime_type)
    print(f"Uploaded file '{file.display_name}' as: {file.uri}")
    return file

def wait_for_files_active(files):
    """Waits for the given files to be active."""
    print("Waiting for file processing...")
    for name in (file.name for file in files):
        file = genai.get_file(name)
        while file.state.name == "PROCESSING":
            print(".", end="", flush=True)
            time.sleep(10)
            file = genai.get_file(name)
        if file.state.name != "ACTIVE":
            raise Exception(f"File {file.name} failed to process")
    print("...all files ready")
    print()

# Model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-2.0-flash-exp",
    generation_config=generation_config,
    system_instruction=(
        "You are an expert at evaluating research papers. Judge if the given paper is publishable or not. "
        "In the output, give the PDF name along with the publishability label (0 for non-publishable, "
        "1 for publishable). The paper’s content, methodology, and findings should correspond to the themes, "
        "focus areas, academic criteria, and quality standards of prestigious conferences. A non-publishable "
        "paper may contain irrelevant, nonsensical, or contradictory content.ONLY GIVE THE OUTPUT AS 0 OR 1"
    ),
)

# Specify the folder containing the files
folder_path = "/content/drive/MyDrive/final_ref"

#with zipfile.ZipFile(folder_path, 'r') as zip_ref:
#    zip_ref.extractall("/tmp/papers")  # Extract to /tmp/papers

#folder_path = "/tmp/papers"

# Get all files from the folder
file_paths = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".pdf")]

def save_results_to_csv(results, output_csv="evaluation_results.csv"):
    """Saves the evaluation result to a CSV file."""
    with open(output_csv, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file,fieldnames=["Paper ID", "Publishable"])
        writer.writeheader()
        writer.writerows(results)
    print(f"Results saved to {output_csv}")

# Process files one by one
results = []
#file_paths=['/content/R003.pdf']
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    try:
        # Upload the file to Gemini
        file = upload_to_gemini(file_path, mime_type="application/pdf")

        # Wait for the file to be ready
        wait_for_files_active([file])

        # Start a chat session and send the file for evaluation
        chat_session = model.start_chat(
            history=[
                {"role": "user", "parts": [file]},
            ]
        )
        response = chat_session.send_message("Please evaluate this paper.Is it Publishable or Not?")

        # Append the result
        paper_name=file.display_name
        publishable=response.text.strip()
        eval_result={"Paper ID":paper_name,"Publishable":publishable}
        results.append(eval_result)
        #print(f"{file.display_name}: {response.text}")

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        results.append(f"{file_path}: Error during processing")


# Print the results
print("\nEvaluation Results:")
for result in results:
    print(result)

save_results_to_csv(results)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing file: /content/drive/MyDrive/final_ref/R001.pdf
# Uploaded file 'R001.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/yjz4qntmorph
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R007.pdf
# Uploaded file 'R007.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/bhte19ps9ofx
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R014.pdf
# Uploaded file 'R014.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/wr8u7yqcjgwf
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R013.pdf
# Uploaded file 'R013.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/pw1ij2fe9llp
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R012.pdf
# Uploaded file 'R012.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/goie97576hxb
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R015.pdf
# Uploaded file 'R015.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/1oapl9kvitfr
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R011.pdf
# Uploaded file 'R011.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/szzqcrxt950q
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R004.pdf
# Uploaded file 'R004.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/82p2dasdtclb
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R006.pdf
# Uploaded file 'R006.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/f4t1tnje9bbq
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R009.pdf
# Uploaded file 'R009.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/als1n9wgfrzk
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R010.pdf
# Uploaded file 'R010.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/g30vwnqhrdmj
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R008.pdf
# Uploaded file 'R008.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/pio9p7rfvnut
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R002.pdf
# Uploaded file 'R002.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/6pma68btyf32
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R005.pdf
# Uploaded file 'R005.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/uupov484312t
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/final_ref/R003.pdf
# Uploaded file 'R003.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/qs3vah6sb9au
# Waiting for file processing...
# ...all files ready
#
#
# Evaluation Results:
# {'Paper ID': 'R001.pdf', 'Publishable': '0'}
# {'Paper ID': 'R007.pdf', 'Publishable': '1'}
# {'Paper ID': 'R014.pdf', 'Publishable': '1'}
# {'Paper ID': 'R013.pdf', 'Publishable': '1'}
# {'Paper ID': 'R012.pdf', 'Publishable': '1'}
# {'Paper ID': 'R015.pdf', 'Publishable': '1'}
# {'Paper ID': 'R011.pdf', 'Publishable': '1'}
# {'Paper ID': 'R004.pdf', 'Publishable': '0'}
# {'Paper ID': 'R006.pdf', 'Publishable': '1'}
# {'Paper ID': 'R009.pdf', 'Publishable': '1'}
# {'Paper ID': 'R010.pdf', 'Publishable': '1'}
# {'Paper ID': 'R008.pdf', 'Publishable': '1'}
# {'Paper ID': 'R002.pdf', 'Publishable': '0'}
# {'Paper ID': 'R005.pdf', 'Publishable': '1'}
# {'Paper ID': 'R003.pdf', 'Publishable': '0'}
# Results saved to evaluation_results.csv

# %%
from sklearn.metrics import accuracy_score, f1_score

# Define ground truth labels for the 15 reference papers
# Replace these with your actual ground truth labels
ground_truth_labels = {
    "R001.pdf": 0,
    "R002.pdf": 0,
    "R003.pdf": 0,
    "R004.pdf": 0,
    "R005.pdf": 0,
    "R006.pdf": 1,
    "R007.pdf": 1,
    "R008.pdf": 1,
    "R009.pdf": 1,
    "R010.pdf": 1,
    "R011.pdf": 1,
    "R012.pdf": 1,
    "R013.pdf": 1,
    "R014.pdf": 1,
    "R015.pdf": 1
}
from sklearn.metrics import accuracy_score, f1_score, classification_report

# Extract ground truth and predictions
true_labels = []
predicted_labels = []

for result in results:
    if isinstance(result, dict):  # Ignore errors in the results
        paper_id = result["Paper ID"]
        if paper_id in ground_truth_labels:
            true_labels.append(ground_truth_labels[paper_id])
            predicted_labels.append(int(result["Publishable"]))  # Convert to int

# Calculate accuracy and F1 score
accuracy = accuracy_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

# Print metrics
print("\nEvaluation Metrics:")
print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"F1 Score: {f1:.2f}")

# Optional: Detailed classification report
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels, target_names=["Non-Publishable", "Publishable"]))
# Out:
# Evaluation Metrics:
# Accuracy: 93.33%
# F1 Score: 0.95
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# Non-Publishable       1.00      0.80      0.89         5
#     Publishable       0.91      1.00      0.95        10
#
#        accuracy                           0.93        15
#       macro avg       0.95      0.90      0.92        15
#    weighted avg       0.94      0.93      0.93        15

# %%
import os
import time
import google.generativeai as genai
from google.colab import drive, userdata
# Configure the Gemini API
import csv

genai.configure(api_key="AIzaSyAbAPEDYFqAAc3f09Ow5OIscgx8Y5OZ_74")

drive.mount('/content/drive')

def upload_to_gemini(path, mime_type=None):
    """Uploads the given file to Gemini."""
    file = genai.upload_file(path, mime_type=mime_type)
    print(f"Uploaded file '{file.display_name}' as: {file.uri}")
    return file

def wait_for_files_active(files):
    """Waits for the given files to be active."""
    print("Waiting for file processing...")
    for name in (file.name for file in files):
        file = genai.get_file(name)
        while file.state.name == "PROCESSING":
            print(".", end="", flush=True)
            time.sleep(10)
            file = genai.get_file(name)
        if file.state.name != "ACTIVE":
            raise Exception(f"File {file.name} failed to process")
    print("...all files ready")
    print()

# Model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-2.0-flash-exp",
    generation_config=generation_config,
    system_instruction=(
        "You are an expert at evaluating research papers. Judge if the given paper is publishable or not. "
        "In the output, give the PDF name along with the publishability label (0 for non-publishable, "
        "1 for publishable). The paper’s content, methodology, and findings should correspond to the themes, "
        "focus areas, academic criteria, and quality standards of prestigious conferences. A non-publishable "
        "paper may contain irrelevant, nonsensical, or contradictory content.ONLY GIVE THE OUTPUT AS 0 OR 1"
    ),
)

# Specify the folder containing the files
folder_path = "/content/drive/MyDrive/Papers-20250112T180905Z-001/Papers"

#with zipfile.ZipFile(folder_path, 'r') as zip_ref:
#    zip_ref.extractall("/tmp/papers")  # Extract to /tmp/papers

#folder_path = "/tmp/papers"

# Get all files from the folder
file_paths = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".pdf")]

def save_results_to_csv(results, output_csv="evaluation_results.csv"):
    """Saves the evaluation result to a CSV file."""
    with open(output_csv, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file,fieldnames=["Paper ID", "Publishable"])
        writer.writeheader()
        writer.writerows(results)
    print(f"Results saved to {output_csv}")

# Process files one by one
results = []
#file_paths=['/content/R003.pdf']
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    try:
        # Upload the file to Gemini
        file = upload_to_gemini(file_path, mime_type="application/pdf")

        # Wait for the file to be ready
        wait_for_files_active([file])

        # Start a chat session and send the file for evaluation
        chat_session = model.start_chat(
            history=[
                {"role": "user", "parts": [file]},
            ]
        )
        response = chat_session.send_message("Please evaluate this paper.Is it Publishable or Not?")

        # Append the result
        paper_name=file.display_name
        publishable=response.text.strip()
        eval_result={"Paper ID":paper_name,"Publishable":publishable}
        results.append(eval_result)
        #print(f"{file.display_name}: {response.text}")

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        results.append(f"{file_path}: Error during processing")


# Print the results
print("\nEvaluation Results:")
for result in results:
    print(result)

save_results_to_csv(results)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P095.pdf
# Uploaded file 'P095.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/wjx9yxwvi2ip
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P012.pdf
# Uploaded file 'P012.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/yj5hyovwid6h
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P014.pdf
# Uploaded file 'P014.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/9rs8gptjb5za
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P052.pdf
# Uploaded file 'P052.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/u7129tb491t8
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P115.pdf
# Uploaded file 'P115.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/g7s12mvg2rao
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P083.pdf
# Uploaded file 'P083.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/5nkm3blc73fd
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P042.pdf
# Uploaded file 'P042.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/wzfl1cfonr3w
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P009.pdf
# Uploaded file 'P009.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/8suzsq8ud02e
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P114.pdf
# Uploaded file 'P114.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/nl1bdr8shivt
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P113.pdf
# Uploaded file 'P113.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/lh159dwd650h
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P131.pdf
# Uploaded file 'P131.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/bl9ejezsa5ku
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P101.pdf
# Uploaded file 'P101.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/e548ftlxyrdw
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P135.pdf
# Uploaded file 'P135.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/89umnwt13ozy
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P046.pdf
# Uploaded file 'P046.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/4k9abxn9pe7i
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P058.pdf
# Uploaded file 'P058.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/6wyp4gk75o2r
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P085.pdf
# Uploaded file 'P085.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/64x6xw10stjg
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P109.pdf
# Uploaded file 'P109.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/
pdf' as: https://generativelanguage.googleapis.com/v1beta/files/pyrt7w9br3kp
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P026.pdf
# Uploaded file 'P026.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/1lcyy3ejzo8r
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P125.pdf
# Uploaded file 'P125.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/gw1iafqwep5c
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P081.pdf
# Uploaded file 'P081.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/vou8wm4zpau4
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P121.pdf
# Uploaded file 'P121.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/ips3fc9p5rne
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P064.pdf
# Uploaded file 'P064.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/5rucj2bddgot
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P029.pdf
# Uploaded file 'P029.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/6k2do5b2ljt1
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P018.pdf
# Uploaded file 'P018.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/x6k76i9qpq2v
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P002.pdf
# Uploaded file 'P002.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/mbn19ydyxix8
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P022.pdf
# Uploaded file 'P022.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/c9wifq08tbzr
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P024.pdf
# Uploaded file 'P024.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/71gvec7q4v4l
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P048.pdf
# Uploaded file 'P048.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/dgjt257bkfkj
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P016.pdf
# Uploaded file 'P016.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/a4zy4o008mda
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P068.pdf
# Uploaded file 'P068.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/lf0mes7apyyx
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P090.pdf
# Uploaded file 'P090.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/ob8wic85hrz2
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P038.pdf
# Uploaded file 'P038.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/wulod1etryow
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P043.pdf
# Uploaded file 'P043.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/hn8fkhta8jh3
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P116.pdf
# Uploaded file 'P116.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/uhwy7ogh7ree
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P013.pdf
# Uploaded file 'P013.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/v2tn6dz98j0a
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P028.pdf
# Uploaded file 'P028.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/yjc4druysvni
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P078.pdf
# Uploaded file 'P078.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/a4ru3isk6z8f
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P126.pdf
# Uploaded file 'P126.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/82kc0giwtgv9
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P041.pdf
# Uploaded file 'P041.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/qijkjxk2z03
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P032.pdf
# Uploaded file 'P032.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/wjdy0c34cvmo
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P100.pdf
# Uploaded file 'P100.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/gew5z00gm47c
# Waiting for file processing...
# ...all files ready
#
# Processing file: /content/drive/MyDrive/Papers-20250112T180905Z-001/Papers/P008.pdf
# Uploaded file 'P008.pdf' as: https://generativelanguage.googleapis.com/v1beta/files/n1vm561x1rki
# Waiting for file processing...
# ...all files ready
#
#
# Evaluation Results:
# {'Paper ID': 'P095', 'Publishable': '1'}
# {'Paper ID': 'P012', 'Publishable': '1'}
# {'Paper ID': 'P014', 'Publishable': '1'}
# {'Paper ID': 'P052', 'Publishable': '1'}
# {'Paper ID': 'P115', 'Publishable': '1'}
# {'Paper ID': 'P083', 'Publishable': '1'}
# {'Paper ID': 'P042', 'Publishable': 'DeepSim_Semantic_Approach_Image_Registration_Evaluation.pdf 1'}
# {'Paper ID': 'P009', 'Publishable': '1'}
# {'Paper ID': 'P114', 'Publishable': '1'}
# {'Paper ID': 'P113', 'Publishable': '1'}
# {'Paper ID': 'P131', 'Publishable': '1'}
# {'Paper ID': 'P101', 'Publishable': '1'}
# {'Paper ID': 'P135', 'Publishable': '1'}
# {'Paper ID': 'P046', 'Publishable': '1'}
# {'Paper ID': 'P058', 'Publishable': '1'}
# {'Paper ID': 'P085', 'Publishable': '1'}
# {'Paper ID': 'P109', 'Publishable': '1'}
# {'Paper ID': 'P055', 'Publishable': '1'}
# {'Paper ID': 'P054', 'Publishable': '1'}
# {'Paper ID': 'P061', 'Publishable': '1'}
# {'Paper ID': 'P103', 'Publishable': '1'}
# {'Paper ID': 'P079', 'Publishable': '1'}
# {'Paper ID': 'P084', 'Publishable': '1'}
# {'Paper ID': 'P004', 'Publishable': '1'}
# {'Paper ID': 'P049', 'Publishable': '1'}
# {'Paper ID': 'P112', 'Publishable': '1'}
# {'Paper ID': 'P057', 'Publishable': '1'}
# {'Paper ID': 'P040', 'Publishable': '1'}
# {'Paper ID': 'P127', 'Publishable': 'Examining_Machine_Learnings_Impact_on_Personal_Privacy.pdf 1'}
# {'Paper ID': 'P091', 'Publishable': '1'}
# {'Paper ID': 'P082', 'Publishable': '1'}
# {'Paper ID': 'P107', 'Publishable': '0'}
# {'Paper ID': 'P122', 'Publishable': 'Short-Term Forecasting of Precipitation Using Satellite Data.pdf 1'}
# {'Paper ID': 'P015', 'Publishable': '1'}
# {'Paper ID': 'P063', 'Publishable': '0'}
# {'Paper ID': 'P010', 'Publishable': '1'}
# {'Paper ID': 'P025', 'Publishable': '1'}
# {'Paper ID': 'P035', 'Publishable': '0'}
# {'Paper ID': 'P120', 'Publishable': '1'}
# {'Paper ID': 'P093', 'Publishable': '1'}
# {'Paper ID': 'P092', 'Publishable': '1'}
# {'Paper ID': 'P019', 'Publishable': '1'}
# {'Paper ID': 'P098', 'Publishable': '0'}
# {'Paper ID': 'P111', 'Publishable': '1'}
# {'Paper ID': 'P037', 'Publishable': '1'}
# {'Paper ID': 'P001', 'Publishable': '1'}
# {'Paper ID': 'P089', 'Publishable': '1'}
# {'Paper ID': 'P021', 'Publishable': '1'}
# {'Paper ID': 'P034', 'Publishable': '1'}
# {'Paper ID': 'P088', 'Publishable': '1'}
# {'Paper ID': 'P124', 'Publishable': '0'}
# {'Paper ID': 'P076', 'Publishable': '0'}
# {'Paper ID': 'P044', 'Publishable': '1'}
# {'Paper ID': 'P117', 'Publishable': '1'}
# {'Paper ID': 'P106', 'Publishable': '0'}
# {'Paper ID': 'P030', 'Publishable': '1'}
# {'Paper ID': 'P074', 'Publishable': '1'}
# {'Paper ID': 'P066', 'Publishable': '1'}
# {'Paper ID': 'P099', 'Publishable': '1'}
# {'Paper ID': 'P006', 'Publishable': '0'}
# {'Paper ID': 'P007', 'Publishable': '1'}
# {'Paper ID': 'P123', 'Publishable': '1'}
# {'Paper ID': 'P011', 'Publishable': '1'}
# {'Paper ID': 'P110', 'Publishable': '1'}
# {'Paper ID': 'P071', 'Publishable': '1'}
# {'Paper ID': 'P059', 'Publishable': '1'}
# {'Paper ID': 'P045', 'Publishable': '1'}
# {'Paper ID': 'P067', 'Publishable': '1'}
# {'Paper ID': 'P003', 'Publishable': '0'}
# {'Paper ID': 'P005', 'Publishable': '1'}
# {'Paper ID': 'P060', 'Publishable': '1'}
# {'Paper ID': 'P108', 'Publishable': '1'}
# {'Paper ID': 'P051', 'Publishable': '1'}
# {'Paper ID': 'P119', 'Publishable': '0'}
# {'Paper ID': 'P096', 'Publishable': '0'}
# {'Paper ID': 'P053', 'Publishable': '0'}
# {'Paper ID': 'P075', 'Publishable': '1'}
# {'Paper ID': 'P087', 'Publishable': '1'}
# {'Paper ID': 'P065', 'Publishable': '1'}
# {'Paper ID': 'P056', 'Publishable': '0'}
# {'Paper ID': 'P050', 'Publishable': '1'}
# {'Paper ID': 'P072', 'Publishable': 'Evaluating_the_Resilience_of_White-Box_Defenses_Against_Adversarial_Examples.pdf 1'}
# {'Paper ID': 'P020', 'Publishable': '0'}
# {'Paper ID': 'P069', 'Publishable': '0'}
# {'Paper ID': 'P134', 'Publishable': '0'}
# {'Paper ID': 'P073', 'Publishable': '0'}
# {'Paper ID': 'P097', 'Publishable': '0'}
# {'Paper ID': 'P128', 'Publishable': '1'}
# {'Paper ID': 'P102', 'Publishable': '1'}
# {'Paper ID': 'P036', 'Publishable': '0'}
# {'Paper ID': 'P023', 'Publishable': '1'}
# {'Paper ID': 'P017', 'Publishable': '1'}
# {'Paper ID': 'P133', 'Publishable': '1'}
# {'Paper ID': 'P031', 'Publishable': '1'}
# {'Paper ID': 'P104', 'Publishable': '1'}
# {'Paper ID': 'P033', 'Publishable': '1'}
# {'Paper ID': 'P039', 'Publishable': '0'}
# {'Paper ID': 'P094', 'Publishable': '0'}
# {'Paper ID': 'P047', 'Publishable': '0'}
# {'Paper ID': 'P129', 'Publishable': '0'}
# {'Paper ID': 'P080', 'Publishable': '1'}
# {'Paper ID': 'P105', 'Publishable': '0'}
# {'Paper ID': 'P027', 'Publishable': 'emoji2vec.pdf 1'}
# {'Paper ID': 'P070', 'Publishable': '0'}
# {'Paper ID': 'P118', 'Publishable': '1'}
# {'Paper ID': 'P077', 'Publishable': '0'}
# {'Paper ID': 'P086', 'Publishable': '0'}
# {'Paper ID': 'P132', 'Publishable': '0'}
# {'Paper ID': 'P130', 'Publishable': '0'}
# {'Paper ID': 'P062', 'Publishable': '1'}
# {'Paper ID': 'P026', 'Publishable': '0'}
# {'Paper ID': 'P125', 'Publishable': '1'}
# {'Paper ID': 'P081', 'Publishable': '0'}
# {'Paper ID': 'P121', 'Publishable': '1'}
# {'Paper ID': 'P064', 'Publishable': '1'}
# {'Paper ID': 'P029', 'Publishable': '1'}
# {'Paper ID': 'P018', 'Publishable': 'plasticity_mechanisms.pdf 1'}
# {'Paper ID': 'P002', 'Publishable': '0'}
# {'Paper ID': 'P022', 'Publishable': '0'}
# {'Paper ID': 'P024', 'Publishable': 'turning_the_tables.pdf 1'}
# {'Paper ID': 'P048', 'Publishable': '0'}
# {'Paper ID': 'P016', 'Publishable': '1'}
# {'Paper ID': 'P068', 'Publishable': '1'}
# {'Paper ID': 'P090', 'Publishable': '1'}
# {'Paper ID': 'P038', 'Publishable': '0'}
# {'Paper ID': 'P043', 'Publishable': '0'}
# {'Paper ID': 'P116', 'Publishable': '1'}
# {'Paper ID': 'P013', 'Publishable': '1'}
# {'Paper ID': 'P028', 'Publishable': '1'}
# {'Paper ID': 'P078', 'Publishable': '0'}
# {'Paper ID': 'P126', 'Publishable': '1'}
# {'Paper ID': 'P041', 'Publishable': '0'}
# {'Paper ID': 'P032', 'Publishable': '0'}
# {'Paper ID': 'P100', 'Publishable': '0'}
# {'Paper ID': 'P008', 'Publishable': '1'}
# Results saved to evaluation_results.csv

# %%
import os
import shutil
import pandas as pd

# Paths
input_folder = "/content/drive/MyDrive/Papers-20250112T180905Z-001/Papers"
output_folder = "/content/drive/MyDrive/Publishable"
csv_file_path = "/content/papers_evaluation.csv"  # Update to actual CSV file path if different

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Filter the Paper IDs with Publishable = 1
publishable_papers = df[df['Publishable'] == 1]['Paper ID']

# Copy files to the new folder
for paper_id in publishable_papers:
    source_path = os.path.join(input_folder, paper_id)
    destination_path = os.path.join(output_folder, paper_id)

    if os.path.exists(source_path):
        shutil.copy(source_path, destination_path)
        print(f"Copied {paper_id} to {output_folder}")
    else:
        print(f"File not found: {paper_id}")

print(f"All publishable papers have been copied to {output_folder}.")
# Out:
# Copied P001.pdf to /content/drive/MyDrive/Publishable
# Copied P004.pdf to /content/drive/MyDrive/Publishable
# Copied P005.pdf to /content/drive/MyDrive/Publishable
# Copied P007.pdf to /content/drive/MyDrive/Publishable
# Copied P008.pdf to /content/drive/MyDrive/Publishable
# Copied P009.pdf to /content/drive/MyDrive/Publishable
# Copied P010.pdf to /content/drive/MyDrive/Publishable
# Copied P011.pdf to /content/drive/MyDrive/Publishable
# Copied P012.pdf to /content/drive/MyDrive/Publishable
# Copied P013.pdf to /content/drive/MyDrive/Publishable
# Copied P014.pdf to /content/drive/MyDrive/Publishable
# Copied P015.pdf to /content/drive/MyDrive/Publishable
# Copied P016.pdf to /content/drive/MyDrive/Publishable
# Copied P017.pdf to /content/drive/MyDrive/Publishable
# Copied P018.pdf to /content/drive/MyDrive/Publishable
# Copied P019.pdf to /content/drive/MyDrive/Publishable
# Copied P021.pdf to /content/drive/MyDrive/Publishable
# Copied P023.pdf to /content/drive/MyDrive/Publishable
# Copied P024.pdf to /content/drive/MyDrive/Publishable
# Copied P025.pdf to /content/drive/MyDrive/Publishable
# Copied P027.pdf to /content/drive/MyDrive/Publishable
# Copied P028.pdf to /content/drive/MyDrive/Publishable
# Copied P029.pdf to /content/drive/MyDrive/Publishable
# Copied P030.pdf to /content/drive/MyDrive/Publishable
# Copied P031.pdf to /content/drive/MyDrive/Publishable
# Copied P033.pdf to /content/drive/MyDrive/Publishable
# Copied P034.pdf to /content/drive/MyDrive/Publishable
# Copied P037.pdf to /content/drive/MyDrive/Publishable
# Copied P040.pdf to /content/drive/MyDrive/Publishable
# Copied P042.pdf to /content/drive/MyDrive/Publishable
# Copied P044.pdf to /content/drive/MyDrive/Publishable
# Copied P045.pdf to /content/drive/MyDrive/Publishable
# Copied P046.pdf to /content/drive/MyDrive/Publishable
# Copied P049.pdf to /content/drive/MyDrive/Publishable
# Copied P050.pdf to /content/drive/MyDrive/Publishable
# Copied P051.pdf to /content/drive/MyDrive/Publishable
# Copied P052.pdf to /content/drive/MyDrive/Publishable
# Copied P054.pdf to /content/drive/MyDrive/Publishable
# Copied P055.pdf to /content/drive/MyDrive/Publishable
# Copied P057.pdf to /content/drive/MyDrive/Publishable
# Copied P058.pdf to /content/drive/MyDrive/Publishable
# Copied P059.pdf to /content/drive/MyDrive/Publishable
# Copied P060.pdf to /content/drive/MyDrive/Publishable
# Copied P061.pdf to /content/drive/MyDrive/Publishable
# Copied P062.pdf to /content/drive/MyDrive/Publishable
# Copied P064.pdf to /content/drive/MyDrive/Publishable
# Copied P065.pdf to /content/drive/MyDrive/Publishable
# Copied P066.pdf to /content/drive/MyDrive/Publishable
# Copied P067.pdf to /content/drive/MyDrive/Publishable
# Copied P068.pdf to /content/drive/MyDrive/Publishable
# Copied P071.pdf to /content/drive/MyDrive/Publishable
# Copied P072.pdf to /content/drive/MyDrive/Publishable
# Copied P074.pdf to /content/drive/MyDrive/Publishable
# Copied P075.pdf to /content/drive/MyDrive/Publishable
# Copied P079.pdf to /content/drive/MyDrive/Publishable
# Copied P080.pdf to /content/drive/MyDrive/Publishable
# Copied P082.pdf to /content/drive/MyDrive/Publishable
# Copied P083.pdf to /content/drive/MyDrive/Publishable
# Copied P084.pdf to /content/drive/MyDrive/Publishable
# Copied P085.pdf to /content/drive/MyDrive/Publishable
# Copied P087.pdf to /content/drive/MyDrive/Publishable
# Copied P088.pdf to /content/drive/MyDrive/Publishable
# Copied P089.pdf to /content/drive/MyDrive/Publishable
# Copied P090.pdf to /content/drive/MyDrive/Publishable
# Copied P091.pdf to /content/drive/MyDrive/Publishable
# Copied P092.pdf to /content/drive/MyDrive/Publishable
# Copied P093.pdf to /content/drive/MyDrive/Publishable
# Copied P095.pdf to /content/drive/MyDrive/Publishable
# Copied P099.pdf to /content/drive/MyDrive/Publishable
# Copied P101.pdf to /content/drive/MyDrive/Publishable
# Copied P102.pdf to /content/drive/MyDrive/Publishable
# Copied P103.pdf to /content/drive/MyDrive/Publishable
# Copied P104.pdf to /content/drive/MyDrive/Publishable
# Copied P108.pdf to /content/drive/MyDrive/Publishable
# Copied P109.pdf to /content/drive/MyDrive/Publishable
# Copied P110.pdf to /content/drive/MyDrive/Publishable
# Copied P111.pdf to /content/drive/MyDrive/Publishable
# Copied P112.pdf to /content/drive/MyDrive/Publishable
# Copied P113.pdf to /content/drive/MyDrive/Publishable
# Copied P114.pdf to /content/drive/MyDrive/Publishable
# Copied P115.pdf to /content/drive/MyDrive/Publishable
# Copied P116.pdf to /content/drive/MyDrive/Publishable
# Copied P117.pdf to /content/drive/MyDrive/Publishable
# Copied P118.pdf to /content/drive/MyDrive/Publishable
# Copied P120.pdf to /content/drive/MyDrive/Publishable
# Copied P121.pdf to /content/drive/MyDrive/Publishable
# Copied P122.pdf to /content/drive/MyDrive/Publishable
# Copied P123.pdf to /content/drive/MyDrive/Publishable
# Copied P125.pdf to /content/drive/MyDrive/Publishable
# Copied P126.pdf to /content/drive/MyDrive/Publishable
# Copied P127.pdf to /content/drive/MyDrive/Publishable
# Copied P128.pdf to /content/drive/MyDrive/Publishable
# Copied P131.pdf to /content/drive/MyDrive/Publishable
# Copied P133.pdf to /content/drive/MyDrive/Publishable
# Copied P135.pdf to /content/drive/MyDrive/Publishable
# All publishable papers have been copied to /content/drive/MyDrive/Publishable.
